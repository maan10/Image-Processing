# %%
'''image read through skyimage  library 

    by: Mohammad Usman 
    Date:  28/12/2021
'''
# Out:
# 'image read through skyimage  library \n\n    by: Mohammad Usman \n    Date:  28/12/2021\n'

# %% [markdown]
# Within the scikit-image package, there are several sample images provided in the data module. Let’s say we want to load a single image to perform a few experiments.  Instead of using an external image, we can simply load one of the images provided within the package!

# %%
from skimage.io import imread, imshow
from skimage import data
image=data.astronaut()          #data contain multiple image like coin, cat, astronaut
img1=data.camera()
imshow(img1)   
imshow(image)

# %% [markdown]
# What if you want to load an image from your machine instead of the ones provided in the package?For this, we can use the imread
# function from skimage.

# %%
# converting image into gray scale.......
import matplotlib.pyplot 
gray_img=imread('E:\\practining image\\flower.png',as_gray=True)
print(gray_img.shape)
imshow(gray_img)
# Out:
# (1180, 786)

# %%
#reading colored image

import matplotlib.pyplot 
gray_img=imread('E:\\practining image\\flower.png',as_gray=False)   # parameter value difference
print(gray_img.shape)
imshow(gray_img)
# Out:
# (1180, 786, 4)
